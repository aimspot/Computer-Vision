# %%
from torchvision.io import read_image
img = read_image("/content/drive/MyDrive/ITMO/CV/Lab_3/data/dataset/train/Apples__Сedar rust/2058.jpg")

# %%
from torchvision.models import alexnet, AlexNet_Weights
from torch.profiler import profile, record_function, ProfilerActivity

# %%
# Step 1: Initialize model with the best available weights
weights = AlexNet_Weights.DEFAULT
model = alexnet(weights=weights)
model.eval()

# Step 2: Initialize the inference transforms
preprocess = weights.transforms()

# Step 3: Apply inference preprocessing transforms
batch = preprocess(img).unsqueeze(0)

with profile(activities=[ProfilerActivity.CPU],
        profile_memory=True, record_shapes=True) as prof:
    model(batch)

print(prof.key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
print(prof.key_averages().table(sort_by="cpu_memory_usage", row_limit=10))
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       aten::empty         0.03%      44.000us         0.03%      44.000us       4.000us       1.85 Mb       1.85 Mb            11
#     aten::max_pool2d_with_indices         2.86%       4.966ms         2.86%       4.966ms       1.655ms       1.01 Mb       1.01 Mb             3
#                  aten::max_pool2d         0.37%     635.000us         2.87%       4.982ms       1.661ms       1.01 Mb     380.25 Kb             3
#                     aten::resize_         0.00%       5.000us         0.00%       5.000us       5.000us      36.00 Kb      36.00 Kb             1
#                       aten::addmm        11.41%      19.789ms        11.43%      19.821ms       6.607ms      35.91 Kb      35.91 Kb             3
#                      aten::conv2d         0.49%     844.000us        81.16%     140.796ms      28.159ms       1.85 Mb           0 b             5
#                 aten::convolution         1.63%       2.823ms        80.68%     139.952ms      27.990ms       1.85 Mb           0 b             5
#                aten::_convolution         0.05%      89.000us        79.05%     137.129ms      27.426ms       1.85 Mb           0 b             5
#          aten::mkldnn_convolution        78.97%     136.983ms        79.00%     137.040ms      27.408ms       1.85 Mb           0 b             5
#                 aten::as_strided_         0.01%      14.000us         0.01%      14.000us       2.800us           0 b           0 b             5
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 173.470ms
#
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      aten::conv2d         0.49%     844.000us        81.16%     140.796ms      28.159ms       1.85 Mb           0 b             5
#                 aten::convolution         1.63%       2.823ms        80.68%     139.952ms      27.990ms       1.85 Mb           0 b             5
#                aten::_convolution         0.05%      89.000us        79.05%     137.129ms      27.426ms       1.85 Mb           0 b             5
#          aten::mkldnn_convolution        78.97%     136.983ms        79.00%     137.040ms      27.408ms       1.85 Mb           0 b             5
#                       aten::empty         0.03%      44.000us         0.03%      44.000us       4.000us       1.85 Mb       1.85 Mb            11
#                  aten::max_pool2d         0.37%     635.000us         2.87%       4.982ms       1.661ms       1.01 Mb     380.25 Kb             3
#     aten::max_pool2d_with_indices         2.86%       4.966ms         2.86%       4.966ms       1.655ms       1.01 Mb       1.01 Mb             3
#         aten::adaptive_avg_pool2d         0.00%       6.000us         1.55%       2.694ms       2.694ms      36.00 Kb           0 b             1
#        aten::_adaptive_avg_pool2d         1.55%       2.682ms         1.55%       2.688ms       2.688ms      36.00 Kb           0 b             1
#                     aten::resize_         0.00%       5.000us         0.00%       5.000us       5.000us      36.00 Kb      36.00 Kb             1
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 173.470ms

# %%
from torchvision.models import vgg16, VGG16_Weights
# Step 1: Initialize model with the best available weights
weights = VGG16_Weights.DEFAULT
model = vgg16(weights=weights)
model.eval()

# Step 2: Initialize the inference transforms
preprocess = weights.transforms()

# Step 3: Apply inference preprocessing transforms
batch = preprocess(img).unsqueeze(0)

with profile(activities=[ProfilerActivity.CPU],
        profile_memory=True, record_shapes=True) as prof:
    model(batch)

print(prof.key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
print(prof.key_averages().table(sort_by="cpu_memory_usage", row_limit=10))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                       aten::empty         0.04%     207.000us         0.04%     207.000us       7.667us      51.68 Mb      51.68 Mb            27
#     aten::max_pool2d_with_indices         5.70%      29.936ms         5.70%      29.936ms       5.987ms      17.51 Mb      17.51 Mb             5
#                     aten::resize_         0.00%       4.000us         0.00%       4.000us       4.000us      98.00 Kb      98.00 Kb             1
#                       aten::addmm         4.10%      21.537ms         4.10%      21.569ms       7.190ms      35.91 Kb      35.91 Kb             3
#                      aten::conv2d         0.02%      81.000us        89.46%     470.209ms      36.170ms      51.68 Mb           0 b            13
#                 aten::convolution         0.07%     354.000us        89.44%     470.128ms      36.164ms      51.68 Mb           0 b            13
#                aten::_convolution         0.03%     181.000us        89.38%     469.774ms      36.136ms      51.68 Mb           0 b            13
#          aten::mkldnn_convolution        89.29%     469.343ms        89.34%     469.593ms      36.123ms      51.68 Mb           0 b            13
#                 aten::as_strided_         0.01%      44.000us         0.01%      44.000us       3.385us           0 b           0 b            13
#                       aten::relu_         0.07%     384.000us         0.64%       3.347ms     223.133us           0 b           0 b            15
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 525.620ms
#
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                              Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      aten::conv2d         0.02%      81.000us        89.46%     470.209ms      36.170ms      51.68 Mb           0 b            13
#                 aten::convolution         0.07%     354.000us        89.44%     470.128ms      36.164ms      51.68 Mb           0 b            13
#                aten::_convolution         0.03%     181.000us        89.38%     469.774ms      36.136ms      51.68 Mb           0 b            13
#          aten::mkldnn_convolution        89.29%     469.343ms        89.34%     469.593ms      36.123ms      51.68 Mb           0 b            13
#                       aten::empty         0.04%     207.000us         0.04%     207.000us       7.667us      51.68 Mb      51.68 Mb            27
#                  aten::max_pool2d         0.01%      28.000us         5.70%      29.964ms       5.993ms      17.51 Mb           0 b             5
#     aten::max_pool2d_with_indices         5.70%      29.936ms         5.70%      29.936ms       5.987ms      17.51 Mb      17.51 Mb             5
#         aten::adaptive_avg_pool2d         0.00%       5.000us         0.08%     406.000us     406.000us      98.00 Kb           0 b             1
#        aten::_adaptive_avg_pool2d         0.08%     396.000us         0.08%     401.000us     401.000us      98.00 Kb           0 b             1
#                     aten::resize_         0.00%       4.000us         0.00%       4.000us       4.000us      98.00 Kb      98.00 Kb             1
# ---------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 525.620ms

# %%
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
# Step 1: Initialize model with the best available weights
model = mobilenet_v2()
model.eval()

# Step 2: Initialize the inference transforms
preprocess = weights.transforms()

# Step 3: Apply inference preprocessing transforms
batch = preprocess(img).unsqueeze(0)

with profile(activities=[ProfilerActivity.CPU],
        profile_memory=True, record_shapes=True) as prof:
    model(batch)

print(prof.key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
print(prof.key_averages().table(sort_by="cpu_memory_usage", row_limit=10))
# Out:
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                             Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      aten::empty         5.87%       5.050ms         5.87%       5.050ms      13.220us      33.57 Mb      33.57 Mb           382
#              aten::empty_strided         2.47%       2.125ms         2.47%       2.125ms      59.028us      23.00 Mb      23.00 Mb            36
#                    aten::resize_         0.09%      79.000us         0.09%      79.000us       2.324us      11.47 Mb      11.47 Mb            34
#       aten::_slow_conv2d_forward        44.00%      37.869ms        44.22%      38.056ms       1.119ms      15.16 Mb       3.70 Mb            34
#                 aten::empty_like         0.08%      72.000us         5.74%       4.942ms      95.038us      25.47 Mb       2.51 Mb            52
#                        aten::add         0.29%     249.000us         0.29%     249.000us      24.900us     845.25 Kb     845.25 Kb            10
#                     aten::conv2d         0.88%     757.000us        67.38%      57.993ms       1.115ms      25.47 Mb     588.00 Kb            52
#         aten::mkldnn_convolution        18.96%      16.314ms        19.04%      16.384ms     910.222us      10.31 Mb     477.75 Kb            18
#                      aten::clone         0.25%     214.000us         5.83%       5.016ms     143.314us      23.29 Mb     294.00 Kb            35
#     aten::_batch_norm_impl_index         4.49%       3.863ms        21.51%      18.512ms     356.000us      25.47 Mb      98.00 Kb            52
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 86.064ms
#
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                             Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                      aten::empty         5.87%       5.050ms         5.87%       5.050ms      13.220us      33.57 Mb      33.57 Mb           382
#                     aten::conv2d         0.88%     757.000us        67.38%      57.993ms       1.115ms      25.47 Mb     588.00 Kb            52
#                aten::convolution         0.43%     373.000us        67.24%      57.868ms       1.113ms      25.47 Mb           0 b            52
#               aten::_convolution         1.14%     984.000us        66.80%      57.495ms       1.106ms      25.47 Mb           0 b            52
#                 aten::batch_norm         0.13%     116.000us        21.63%      18.617ms     358.019us      25.47 Mb      85.75 Kb            52
#     aten::_batch_norm_impl_index         4.49%       3.863ms        21.51%      18.512ms     356.000us      25.47 Mb      98.00 Kb            52
#          aten::native_batch_norm        11.19%       9.629ms        17.01%      14.638ms     281.500us      25.47 Mb    -305.31 Kb            52
#                 aten::empty_like         0.08%      72.000us         5.74%       4.942ms      95.038us      25.47 Mb       2.51 Mb            52
#                  aten::hardtanh_         2.05%       1.763ms         9.18%       7.897ms     225.629us      23.29 Mb           0 b            35
#                      aten::clone         0.25%     214.000us         5.83%       5.016ms     143.314us      23.29 Mb     294.00 Kb            35
# --------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 86.064ms
